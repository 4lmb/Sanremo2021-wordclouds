# %%
from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
import pandas as pd
from PIL import Image
import random

# %matplotlib inline

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(10, 10%%, %d%%)" % random.randint(20, 70)

# %%
def masked_cloud(name):
    text=open (name+'.txt').read()
    mask = np.array(Image.open(name+'.png'))
    wc = WordCloud(background_color="black", max_words=50, mask=mask, 
               stopwords=stp, contour_width=3, contour_color='grey').generate(text)

    #save
    wc.recolor(color_func=grey_color_func).to_file(name+'_words.png')
    # show
    plt.imshow(wc.recolor(color_func=grey_color_func), interpolation='bilinear')
    plt.axis("off")
    plt.figure()
    plt.axis("off")
    plt.show()

# %%
#Define stopwords
exep = set(['del', 'un', 'di', 'c' ,'la', 'che', 'il', 'l', 'la', 'un', 'allo', 'nel', 'e', 'dell', 
            'gli',  'mi' , 'sti', 'ti', 'ce', 'al' , 'le', 'sta' , 's', 'non', 'è',
            'una', 'vi', 'dal' , 'lo', 'ci', 'nella', 'da', 'cos',  'sto', 'ed', 'ad', 'alle', 'per',
            'con', 'na', 'delle', 'tra', 'coi', 'li', 'una', 'dai', 'ai', 'cui'])
stp = set(STOPWORDS).union(exep)

# %%
#Willie Peyote
print('“Mai dire mai (La locura)” di Willie Peyote')
masked_cloud('willie')
# Out:
# “Mai dire mai (La locura)” di Willie Peyote

# %%
#Extraliscio's word cloud
print('“Bianca luce nera” di Extraliscio e Davide Toffolo')
masked_cloud('extraliscio')
# Out:
# “Bianca luce nera” di Extraliscio e Davide Toffolo

# %%
#La rappresentante di lista's word cloud
print('“Amare” di La Rappresentante di Lista')
masked_cloud('rappresentante')
# Out:
# “Amare” di La Rappresentante di Lista

# %%
#Annalisa's word cloud
print('“Dieci” di Annalisa')
masked_cloud('annalisa')
# Out:
# “Dieci” di Annalisa

# %%
#Fulminacci's word cloud
print('“Santa Marinella” di Fulminacci')
masked_cloud('fulminacci')
# Out:
# “Santa Marinella” di Fulminacci

# %%
#Orietta Berti's word cloud
print('“Quando ti sei innamorato” di Orietta Berti')
masked_cloud('orietta')
# Out:
# “Quando ti sei innamorato” di Orietta Berti

# %%
#Random
print('“Torno a te” di Random')
masked_cloud('random')
# Out:
# “Torno a te” di Random

# %%
#Renga
print('“Quando trovo te” di Francesco Renga')
masked_cloud('renga')
# Out:
# “Quando trovo te” di Francesco Renga

# %%
#Noemi
print('“Glicine” di Noemi')
masked_cloud('noemi')
# Out:
# “Glicine” di Noemi

# %%
#Gazzè
print('“Il farmacista” di Max Gazzè')
masked_cloud('gazze')
# Out:
# “Il farmacista” di Max Gazzè

# %%
#Irama
print('“La genesi del tuo colore” di Irama')
masked_cloud('irama')
# Out:
# “La genesi del tuo colore” di Irama

# %%
#Gio Evan
print('“Arnica” di Gio Evan')
masked_cloud('evan')
# Out:
# “Arnica” di Gio Evan

# %%
#Lo stato sociale
print('“Combat Pop” di Lo Stato Sociale')
masked_cloud('stato')
# Out:
# “Combat Pop” di Lo Stato Sociale

# %%
#Ghemon
print('“Momento perfetto” di Ghemon')
masked_cloud('ghemon')
# Out:
# “Momento perfetto” di Ghemon

# %%
#Gaia
print('“Cuore amaro” di Gaia')
masked_cloud('gaia')
# Out:
# “Cuore amaro” di Gaia

# %%
#Francesca Michielin e Fedez
print('“Chiamami per nome” di Francesca Michielin e Fedez')
masked_cloud('fedez')
# Out:
# “Chiamami per nome” di Francesca Michielin e Fedez

# %%
#Fasma
print('“Parlami” di Fasma')
masked_cloud('fasma')
# Out:
# “Parlami” di Fasma

# %%
#Maneskin
print('“Zitti e buoni” dei Maneskin')
masked_cloud('maneskin')
# Out:
# “Zitti e buoni” dei Maneskin

# %%
#Malika Ayane
print('“Ti piaci così” di Malika Ayane')
masked_cloud('malika')
# Out:
# “Ti piaci così” di Malika Ayane

# %%
#Madame
print('“Voce” di Madame')
masked_cloud('madame')
# Out:
# “Voce” di Madame

# %%
#Aiello
print('“Ora” di Aiello')
masked_cloud('aiello')
# Out:
# “Ora” di Aiello

# %%
#Arisa
print('“Potevi dare di più” di Arisa')
masked_cloud('arisa')
# Out:
# “Potevi dare di più” di Arisa

# %%
#Bugo
print('“E invece si” di Bugo')
masked_cloud('bugo')
# Out:
# “E invece si” di Bugo

# %%
#Colapesce e Dimartino
print('“Musica leggerissima” di Colapesce e Dimartino')
masked_cloud('colapesce')
# Out:
# “Musica leggerissima” di Colapesce e Dimartino

# %%
#Coma_cose
print('“Fiamme negli occhi” di Coma_Cose')
masked_cloud('comacose')
# Out:
# “Fiamme negli occhi” di Coma_Cose

# %%
#Ermal Meta
print('“Un milione di cose da dirti” di Ermal Meta')
masked_cloud('ermal')
# Out:
# “Un milione di cose da dirti” di Ermal Meta
